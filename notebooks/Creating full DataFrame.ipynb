# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

from twitpol import config, db

# %%
pd.set_option('display.max_columns', 999)

# %%
host = 'database-2.czpegg91dqsv.us-east-2.rds.amazonaws.com'
port = 3306
user = 'admin'
password = 'dbpass111'
charset = 'utf8'
database = 'test_2'

db_str = f'mysql+pymysql://{user}:{password}@{host}:{port}/'
engine = create_engine(db_str)
engine.connect().execute(f"CREATE DATABASE IF NOT EXISTS {database};")
db_str_new = db_str + database
engine_new = create_engine(db_str_new)
# Out:
# /home/ubuntu/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1007, "Can't create database 'test_2'; database exists")
#   result = self._query(query)

# %%
engine = db.get_db_engine(create_database=False)

# %%
pd.read_sql('SELECT COUNT(*) FROM tweets;', con=engine)
# Out:
#    COUNT(*)
# 0   2199798

# %%
test = pd.read_sql('SELECT * FROM tweets LIMIT 50;', con=engine)
test.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0      0  1102357988264669184  1102353254069891073  1551657599000
# 1      1  1102357982329823232  1102345807649558528  1551657598000
# 2      2  1102357980681388032  1102312496617074689  1551657598000
# 3      3  1102357975090585600  1102357975090585600  1551657596000
# 4      4  1102357971550507008  1102348709373849600  1551657595000
#
#                   date timezone place  \
# 0  2019-03-03 23:59:59      UTC
# 1  2019-03-03 23:59:58      UTC
# 2  2019-03-03 23:59:58      UTC
# 3  2019-03-03 23:59:56      UTC
# 4  2019-03-03 23:59:55      UTC
#
#                                                tweet hashtags cashtags  \
# 0  before anyone else tries to comment about bern...       []       []
# 1                            American citizens Bern!       []       []
# 2         Who was and who is Bernie, anyone knows. ?       []       []
# 3  COMMENTARY: Unless you are one of the few who ...       []       []
# ...

# %%
# warren = pd.read_sql(f'SELECT * FROM tweets WHERE name = "WARREN" LIMIT 100000;', con=engine)
# warren.to_csv('DATA/testWarren.csv')

# %%
warren2 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-07-00 00:00:00") AND (name = "WARREN") LIMIT 20000;', con = engine)
warren2.to_csv('DATA/WARREN2.csv')
warren2.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0      0  1145844442777169920  1145720088533897217  1562025578000
# 1      1  1145844395138146306  1145844395138146306  1562025567000
# 2      2  1145844316537012225  1145842051092635648  1562025548000
# 3      3  1145844094662565889  1145844094662565889  1562025495000
# 4      4  1145844003688112128  1145844003688112128  1562025473000
#
#                   date timezone place  \
# 0  2019-07-01 23:59:38      UTC
# 1  2019-07-01 23:59:27      UTC
# 2  2019-07-01 23:59:08      UTC
# 3  2019-07-01 23:58:15      UTC
# 4  2019-07-01 23:57:53      UTC
#
#                                                tweet     hashtags cashtags  \
# 0  and he was spared elizabeth warren. wait until...           []       []
# 1  Are they as mean as you falsely identifying yo...           []       []
# 2  We will & Please Read my Page, I Send Out all ...           []       []
# ...

# %%
warren2.t
# Out:
#        index                   id      conversation_id     created_at  \
# 19995    203  1151258405472002048  1151258405472002048  1563316367000
# 19996    204  1151258217021956103  1151240819745198081  1563316322000
# 19997    205  1151258196985561090  1148631616941711360  1563316318000
# 19998    206  1151258051887939595  1151258051887939595  1563316283000
# 19999    207  1151257862448005122  1151189818639917058  1563316238000
#
#                       date timezone place  \
# 19995  2019-07-16 22:32:47      UTC
# 19996  2019-07-16 22:32:02      UTC
# 19997  2019-07-16 22:31:58      UTC
# 19998  2019-07-16 22:31:23      UTC
# 19999  2019-07-16 22:30:38      UTC
#
#                                                    tweet  \
# 19995  President Elizabeth Warren won’t EVEN #Preside...
# 19996  let's be very clear:\nelizabeth warren is a tr...
# 19997  You have our 2 votes. We hope you Win the Pres...
# 19998  California Poll: Elizabeth Warren Surges Past ...
# ...

# %%
warren3 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-07-16 22:00:00") AND (name = "WARREN") LIMIT 50000;', con = engine)
warren3.to_csv('DATA/WARREN3.csv')
warren3.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0      0  1151279975808602112  1151279975808602112  1563321510000
# 1      1  1151279951074795522  1151279951074795522  1563321504000
# 2      2  1151279852064006144  1151279852064006144  1563321481000
# 3      3  1151279840185724929  1151279840185724929  1563321478000
# 4      4  1151279782212046848  1151279782212046848  1563321464000
#
#                   date timezone place  \
# 0  2019-07-16 23:58:30      UTC
# 1  2019-07-16 23:58:24      UTC
# 2  2019-07-16 23:58:01      UTC
# 3  2019-07-16 23:57:58      UTC
# 4  2019-07-16 23:57:44      UTC
#
#                                                tweet        hashtags cashtags  \
# 0  #TuckFrump Elizabeth Warren had the perfect re...  ['#tuckfrump']       []
# 1  *taps mic* Elizabeth Warren's immigration poli...              []       []
# 2  Peter Thiel Says Elizabeth Warren is the Most ...              []       []
# ...

# %%
warren3.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995   1838  1162456657810657280  1162456657810657280  1565986239000
# 49996   1839  1162456521306988549  1162456521306988549  1565986206000
# 49997   1840  1162456479493959685  1162456479493959685  1565986196000
# 49998   1841  1162456465677979648  1162456465677979648  1565986193000
# 49999   1842  1162456443737595904  1162456443737595904  1565986188000
#
#                       date timezone place  \
# 49995  2019-08-16 20:10:39      UTC
# 49996  2019-08-16 20:10:06      UTC
# 49997  2019-08-16 20:09:56      UTC
# 49998  2019-08-16 20:09:53      UTC
# 49999  2019-08-16 20:09:48      UTC
#
#                                                    tweet hashtags cashtags  \
# 49995  Elizabeth Warren's Plan For Indian Tribes Incl...       []       []
# 49996  Bernie Sanders Supporter Files Labor Complaint...       []       []
# 49997  Elizabeth Warren Was Filmed Literally Running ...       []       []
# ...

# %%
warren4 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-08-16 20:00:00") AND (name = "WARREN") LIMIT 100000;', con = engine)
warren4.to_csv('DATA/WARREN4.csv')
warren4.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0     40  1162514351602962432  1162514351602962432  1565999994000
# 1     41  1162514330480517126  1162514330480517126  1565999989000
# 2     42  1162514325166350336  1162514325166350336  1565999988000
# 3     43  1162514318161776641  1162514318161776641  1565999986000
# 4     44  1162514256463634433  1162514256463634433  1565999971000
#
#                   date timezone place  \
# 0  2019-08-16 23:59:54      UTC
# 1  2019-08-16 23:59:49      UTC
# 2  2019-08-16 23:59:48      UTC
# 3  2019-08-16 23:59:46      UTC
# 4  2019-08-16 23:59:31      UTC
#
#                                                tweet hashtags cashtags  \
# 0  When Elizabeth Warren Kindly Ignored That I Sm...       []       []
# 1  Elizabeth Warren is awesome! I would vote for ...       []       []
# 2  INBOX: Congresswoman Deb Haaland to Campaign f...       []       []
# 3  If you didn’t already have enough reason to su...       []       []
# ...

# %%
warren5 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-03 21:00:00") AND (name = "WARREN") LIMIT 100000;', con = engine)
warren5.to_csv('DATA/WARREN5.csv')
warren5.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0      0  1179877810183327745  1179875183030607873  1570139765000
# 1      1  1179877798749655041  1179877798749655041  1570139762000
# 2      2  1179877786984620032  1179877786984620032  1570139760000
# 3      3  1179877754625576960  1179877754625576960  1570139752000
# 4      4  1179877732898881537  1179877732898881537  1570139747000
#
#                   date timezone place  \
# 0  2019-10-03 21:56:05      UTC
# 1  2019-10-03 21:56:02      UTC
# 2  2019-10-03 21:56:00      UTC
# 3  2019-10-03 21:55:52      UTC
# 4  2019-10-03 21:55:47      UTC
#
#                                                tweet          hashtags  \
# 0                 duuude is that elizabeth warren ??                []
# 1  So how does Elizabeth (POCAHONTAS) Warren only...                []
# 2  Remember, Wall Street supports Trump or Biden....                []
# 3  With Vin Diesel and Cougar2020 I thought Eliza...  ['#cougars2020']
# ...

# %%
warren5.shape
# Out:
# (97164, 31)

# %% [markdown]
# ## SANDERS

# %%
sanders1 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-03-03 00:00:00") AND (name = "SANDERS") LIMIT 200000;', con = engine)
sanders1.to_csv('DATA/sanders1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-70d115a87562> in <module>
#       1 sanders1 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-03-03 00:00:00") AND (name = "SANDERS") LIMIT 200000;', con = engine)
#       2 sanders1.to_csv('DATA/sanders1.csv')
# ----> 3 sander1.tail()
#
# NameError: name 'sander1' is not defined

# %%
sanders1.tail()
# Out:
#         index                   id      conversation_id     created_at  \
# 199995    560  1131709069541150720  1131658573300359169  1558655442000
# 199996    561  1131709034703335424  1130607146033451008  1558655434000
# 199997    562  1131709034212548608  1131690187090796544  1558655434000
# 199998    563  1131709030957801474  1131561894031110144  1558655433000
# 199999    564  1131708995285245952  1131697063178252293  1558655425000
#
#                        date timezone place  \
# 199995  2019-05-23 23:50:42      UTC
# 199996  2019-05-23 23:50:34      UTC
# 199997  2019-05-23 23:50:34      UTC
# 199998  2019-05-23 23:50:33      UTC
# 199999  2019-05-23 23:50:25      UTC
#
#                                                     tweet hashtags cashtags  \
# 199995  "Crazy Bernie!" Says the calm, rational president       []       []
# 199996  Any more youcant even talk about it or you are...       []       []
# ...

# %%
sanders2 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-05-23 23:00:00") AND (name = "SANDERS") LIMIT 200000;', con = engine)
sanders2.to_csv('DATA/sanders2.csv')
sanders2.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 71543   1875  1165402644493434880  1165307785950781440  1566688617000
# 71544   1876  1165402634494390277  1142554496926736384  1566688614000
# 71545   1877  1165402633013583872  1162769457347006465  1566688614000
# 71546   1878  1165402626458103809  1165400567067369473  1566688612000
# 71547   1879  1165402624918769664  1165402624918769664  1566688612000
#
#                       date timezone place  \
# 71543  2019-08-24 23:16:57      UTC
# 71544  2019-08-24 23:16:54      UTC
# 71545  2019-08-24 23:16:54      UTC
# 71546  2019-08-24 23:16:52      UTC
# 71547  2019-08-24 23:16:52      UTC
#
#                                                    tweet hashtags cashtags  \
# 71543  Bernie:\n1st, eliminate cultural & political s...       []       []
# 71544                      Bernie is the ultimate phony.       []       []
# 71545  How is your three houses Bernie?! Sounds like ...       []       []
# ...

# %%
sanders3 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-08-24 00:00:00") AND (name = "SANDERS") LIMIT 200000;', con = engine)
sanders3.to_csv('DATA/sanders3.csv')
sanders3.tail()
# Out:
#       index                   id      conversation_id     created_at  \
# 1875   1875  1165402644493434880  1165307785950781440  1566688617000
# 1876   1876  1165402634494390277  1142554496926736384  1566688614000
# 1877   1877  1165402633013583872  1162769457347006465  1566688614000
# 1878   1878  1165402626458103809  1165400567067369473  1566688612000
# 1879   1879  1165402624918769664  1165402624918769664  1566688612000
#
#                      date timezone place  \
# 1875  2019-08-24 23:16:57      UTC
# 1876  2019-08-24 23:16:54      UTC
# 1877  2019-08-24 23:16:54      UTC
# 1878  2019-08-24 23:16:52      UTC
# 1879  2019-08-24 23:16:52      UTC
#
#                                                   tweet hashtags cashtags  \
# 1875  Bernie:\n1st, eliminate cultural & political s...       []       []
# 1876                      Bernie is the ultimate phony.       []       []
# 1877  How is your three houses Bernie?! Sounds like ...       []       []
# ...

# %%
sanders3.head()
# Out:
#    index                   id      conversation_id     created_at  \
# 0      0  1165413471942524929  1165345530685214720  1566691198000
# 1      1  1165413464367456256  1165345530685214720  1566691196000
# 2      2  1165413463016890368  1165367147393998848  1566691196000
# 3      3  1165413461989482497  1165385965180841984  1566691196000
# 4      4  1165413458801766401  1165327628825284610  1566691195000
#
#                   date timezone place  \
# 0  2019-08-24 23:59:58      UTC
# 1  2019-08-24 23:59:56      UTC
# 2  2019-08-24 23:59:56      UTC
# 3  2019-08-24 23:59:56      UTC
# 4  2019-08-24 23:59:55      UTC
#
#                                                tweet hashtags cashtags  \
# 0        All paid for by government. Not the person.       []       []
# 1    There’s nothing left to do but laugh at you ???       []       []
# 2  You mean Bernie-hating Mother Jones, whose art...       []       []
# 3                                     Bernie or Yang       []       []
# ...

# %% [markdown]
# ## Harris

# %%
harris1 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-03-00 00:00:00") AND (name = "HARRIS") LIMIT 100000;', con = engine)
harris1.to_csv('DATA/harris1.csv')
harris1.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995   1542  1127993986185080832  1127871110010277888  1557769698000
# 99996   1543  1127993984373145601  1127379203949641728  1557769697000
# 99997   1544  1127993921395666944  1127990801685012480  1557769682000
# 99998   1545  1127993902508720128  1127944029528784897  1557769678000
# 99999   1546  1127993898171809792  1127993898171809792  1557769677000
#
#                       date timezone place  \
# 99995  2019-05-13 17:48:18      UTC
# 99996  2019-05-13 17:48:17      UTC
# 99997  2019-05-13 17:48:02      UTC
# 99998  2019-05-13 17:47:58      UTC
# 99999  2019-05-13 17:47:57      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  I honestly think Biden will be the ultimate ca...       []       []
# 99996                      Kamala is an amazing woman!!!       []       []
# 99997                                kamala harris- acab       []       []
# ...

# %%
harris2 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-05-13 17:00:00") AND (name = "HARRIS") LIMIT 100000;', con = engine)
harris2.to_csv('DATA/harris2.csv')
harris2.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995  14071  1146609553364127745  1146583681982746626  1562207995000
# 99996  14072  1146609534179237888  1146609534179237888  1562207990000
# 99997  14073  1146609526524694528  1146577028335824896  1562207988000
# 99998  14074  1146609459592138752  1146609459592138752  1562207972000
# 99999  14075  1146609451006218241  1146563635428220929  1562207970000
#
#                       date timezone place  \
# 99995  2019-07-04 02:39:55      UTC
# 99996  2019-07-04 02:39:50      UTC
# 99997  2019-07-04 02:39:48      UTC
# 99998  2019-07-04 02:39:32      UTC
# 99999  2019-07-04 02:39:30      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  Kamala Harris your Followers have no Following...       []       []
# 99996  Kamala Harris LOUDLY Pushes Trump To War  http...       []       []
# 99997  Isn’t 1/1024th% African American Kamala his aunt?       []       []
# ...

# %%
harris3 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-07-04 00:00:00") AND (name = "HARRIS") LIMIT 100000;', con = engine)
harris3.to_csv('DATA/harris3.csv')
harris3.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995    110  1167218690066132992  1166828946249437184  1567121596000
# 99996    111  1167218672588312580  1167216792458223616  1567121592000
# 99997    112  1167218629617704960  1167218629617704960  1567121581000
# 99998    113  1167218599305469952  1167218599305469952  1567121574000
# 99999    114  1167218594058571777  1167218594058571777  1567121573000
#
#                       date timezone place  \
# 99995  2019-08-29 23:33:16      UTC
# 99996  2019-08-29 23:33:12      UTC
# 99997  2019-08-29 23:33:01      UTC
# 99998  2019-08-29 23:32:54      UTC
# 99999  2019-08-29 23:32:53      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995    Watch the hubby ...Kamala likes the married men       []       []
# 99996  Matt v Jen in court.\n\nDaredevil dealing with...       []       []
# 99997  Kamala Harris Raided David Daleiden’s Home, St...       []       []
# ...

# %%
harris3.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995    110  1167218690066132992  1166828946249437184  1567121596000
# 99996    111  1167218672588312580  1167216792458223616  1567121592000
# 99997    112  1167218629617704960  1167218629617704960  1567121581000
# 99998    113  1167218599305469952  1167218599305469952  1567121574000
# 99999    114  1167218594058571777  1167218594058571777  1567121573000
#
#                       date timezone place  \
# 99995  2019-08-29 23:33:16      UTC
# 99996  2019-08-29 23:33:12      UTC
# 99997  2019-08-29 23:33:01      UTC
# 99998  2019-08-29 23:32:54      UTC
# 99999  2019-08-29 23:32:53      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995    Watch the hubby ...Kamala likes the married men       []       []
# 99996  Matt v Jen in court.\n\nDaredevil dealing with...       []       []
# 99997  Kamala Harris Raided David Daleiden’s Home, St...       []       []
# ...

# %%
harris4 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-08-29 23:00:00") AND (name = "HARRIS") LIMIT 50000;', con = engine)
harris4.to_csv('DATA/harris4.csv')
harris4.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995   2466  1172314336322191362  1172314336322191362  1568336492000
# 49996   2467  1172314335579758592  1172314335579758592  1568336492000
# 49997   2468  1172314334732488704  1172307772374843393  1568336492000
# 49998   2469  1172314333885300737  1172314333885300737  1568336492000
# 49999   2470  1172314333360975873  1172314333360975873  1568336492000
#
#                       date timezone place  \
# 49995  2019-09-13 01:01:32      UTC
# 49996  2019-09-13 01:01:32      UTC
# 49997  2019-09-13 01:01:32      UTC
# 49998  2019-09-13 01:01:32      UTC
# 49999  2019-09-13 01:01:32      UTC
#
#                                                    tweet        hashtags  \
# 49995                 Kamala Harris is drunk. #demdebate  ['#demdebate']
# 49996  Several of the candidates praise Beto O'Rourke...  ['#demdebate']
# 49997                   Im not about to play with Kamala              []
# ...

# %%
harris5 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-09-13 01:00:00") AND (name = "HARRIS") LIMIT 50000;', con = engine)
harris5.to_csv('DATA/harris5.csv')
harris5.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995    610  1182775879958704130  1182772501073543169  1570830719000
# 49996    611  1182775859209474048  1182588459736879105  1570830714000
# 49997    612  1182775792515850242  1182775576928686082  1570830698000
# 49998    613  1182775774757249024  1182775774757249024  1570830694000
# 49999    614  1182775732881285121  1182732924384206849  1570830684000
#
#                       date timezone place  \
# 49995  2019-10-11 21:51:59      UTC
# 49996  2019-10-11 21:51:54      UTC
# 49997  2019-10-11 21:51:38      UTC
# 49998  2019-10-11 21:51:34      UTC
# 49999  2019-10-11 21:51:24      UTC
#
#                                                    tweet hashtags cashtags  \
# 49995  Kamala you don’t need to do anything nationwid...       []       []
# 49996  Chase said he watched the full interview. He's...       []       []
# 49997  My brain generated this take on its own, fed t...       []       []
# ...

# %%
harris6 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-11 21:50:00") AND (name = "HARRIS") LIMIT 50000;', con = engine)
harris6.to_csv('DATA/harris6.csv')
harris6.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995    607  1192936924715110400  1192625739067097088  1573253301000
# 49996    608  1192936921309175808  1192857564557524994  1573253300000
# 49997    609  1192936892389642242  1192923159055388672  1573253293000
# 49998    610  1192936804263104514  1192936804263104514  1573253272000
# 49999    611  1192936775024439297  1192934803701665792  1573253265000
#
#                       date timezone place  \
# 49995  2019-11-08 22:48:21      UTC
# 49996  2019-11-08 22:48:20      UTC
# 49997  2019-11-08 22:48:13      UTC
# 49998  2019-11-08 22:47:52      UTC
# 49999  2019-11-08 22:47:45      UTC
#
#                                                    tweet  \
# 49995  #KamalaHarris2020 #yeswekam #KHive pic.twitter...
# 49996                                             MAGAt.
# 49997  Okay if you have a better plan go make it.or l...
# 49998  Does Britain need a written constitution after...
# ...

# %% [markdown]
# ## BIDEN

# %%
biden1 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-03-00 00:00:00") AND (name = "BIDEN") LIMIT 100000;', con = engine)
biden1.to_csv('DATA/biden1.csv')
biden1.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995   5675  1128648199370153984  1128648199370153984  1557925674000
# 99996   5676  1128648181598887936  1128644567031537665  1557925670000
# 99997   5677  1128648155237691392  1128384484867371008  1557925664000
# 99998   5678  1128648143925420032  1128648143925420032  1557925661000
# 99999   5679  1128648142163972097  1128642799090458624  1557925661000
#
#                       date timezone place  \
# 99995  2019-05-15 13:07:54      UTC
# 99996  2019-05-15 13:07:50      UTC
# 99997  2019-05-15 13:07:44      UTC
# 99998  2019-05-15 13:07:41      UTC
# 99999  2019-05-15 13:07:41      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  Do not ever fucking tell me Joe Biden is ‘elec...       []       []
# 99996  You do give better brain than Joe Biden, i’ve ...       []       []
# 99997         Stay in the truck Joe.  Bernie's got this.       []       []
# ...

# %%
biden2 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-05-15 13:00:00") AND (name = "BIDEN") LIMIT 100000;', con = engine)
biden2.to_csv('DATA/biden2.csv')
biden2.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995   7426  1175083666164371457  1174856562898128897  1568996752000
# 99996   7427  1175083661269569536  1175069915151253512  1568996751000
# 99997   7428  1175083634304397313  1174836649651367936  1568996745000
# 99998   7429  1175083633004228608  1174867961108213761  1568996744000
# 99999   7430  1175083626272296967  1175083626272296967  1568996743000
#
#                       date timezone place  \
# 99995  2019-09-20 16:25:52      UTC
# 99996  2019-09-20 16:25:51      UTC
# 99997  2019-09-20 16:25:45      UTC
# 99998  2019-09-20 16:25:44      UTC
# 99999  2019-09-20 16:25:43      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  Rudy came on to degrade Joe Biden\n....over an...       []       []
# 99996                 15 million according to Joe Biden.       []       []
# 99997                                      Joe Biden duh       []       []
# ...

# %%
biden3 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-09-20 16:00:00") AND (name = "BIDEN") LIMIT 50000;', con = engine)
biden3.to_csv('DATA/biden3.csv')
biden3.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995   2551  1180242835716493312  1180242480991748097  1570226794000
# 49996   2552  1180242835347509248  1180242835347509248  1570226794000
# 49997   2553  1180242821262872577  1180242821262872577  1570226791000
# 49998   2554  1180242816590462976  1180199673245683713  1570226789000
# 49999   2555  1180242803093364736  1180242803093364736  1570226786000
#
#                       date timezone place  \
# 49995  2019-10-04 22:06:34      UTC
# 49996  2019-10-04 22:06:34      UTC
# 49997  2019-10-04 22:06:31      UTC
# 49998  2019-10-04 22:06:29      UTC
# 49999  2019-10-04 22:06:26      UTC
#
#                                                    tweet hashtags cashtags  \
# 49995  And those soybean Farmers whose crops are rott...       []       []
# 49996  UKRAINE SCANDAL EXPLAINED: Chalkboard on DNC C...       []       []
# 49997  Why hasn't anyone realized the investigation o...       []       []
# ...

# %%
biden4 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-04 22:00:00") AND (name = "BIDEN") LIMIT 100000;', con = engine)
biden4.to_csv('DATA/biden4.csv')
biden4.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 67725   8499  1192592736479662080  1192533455663333376  1573171240000
# 67726   8500  1192592639071113221  1192591650071175168  1573171217000
# 67727   8501  1192592637728972800  1192590165241405442  1573171216000
# 67728   8502  1192592620457021442  1192592620457021442  1573171212000
# 67729   8503  1192592592447295491  1192592592447295491  1573171205000
#
#                       date timezone place  \
# 67725  2019-11-08 00:00:40      UTC
# 67726  2019-11-08 00:00:17      UTC
# 67727  2019-11-08 00:00:16      UTC
# 67728  2019-11-08 00:00:12      UTC
# 67729  2019-11-08 00:00:05      UTC
#
#                                                    tweet  \
# 67725                                          joe biden
# 67726                      Is that man's name Joe Biden?
# 67727  Hey, @CillizzaCNN: I know you're not very good...
# 67728  ? Donald Trump ad misleads about Joe Biden, Uk...
# ...

# %% [markdown]
# ## Buttigieg

# %%
Buttigieg1 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-03-00 00:00:00") AND (name = "BUTTIGIEG") LIMIT 100000;', con = engine)
Buttigieg1.to_csv('DATA/Buttigieg1.csv')
Buttigieg1.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995  13538  1118342630591488000  1118342630591488000  1555468635000
# 99996  13539  1118342622345605121  1118218878100869120  1555468633000
# 99997  13540  1118342567769206786  1118102012246228992  1555468620000
# 99998  13541  1118342544482500608  1118341926925807616  1555468615000
# 99999  13542  1118342534995021825  1117496230307696640  1555468612000
#
#                       date timezone place  \
# 99995  2019-04-17 02:37:15      UTC
# 99996  2019-04-17 02:37:13      UTC
# 99997  2019-04-17 02:37:00      UTC
# 99998  2019-04-17 02:36:55      UTC
# 99999  2019-04-17 02:36:52      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  Democrats might want to get their act together...       []       []
# 99996  Yep Pete has yet to reach reality as who exact...       []       []
# 99997  Hi Keiko, thanks for looking into that. I lear...       []       []
# ...

# %%
Buttigieg2 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-04-17 02:00:00") AND (name = "BUTTIGIEG") LIMIT 100000;', con = engine)
Buttigieg2.to_csv('DATA/Buttigieg2.csv')
Buttigieg2.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995   1647  1136797782809894914  1136797782809894914  1559868686000
# 99996   1648  1136797534335094786  1136797534335094786  1559868627000
# 99997   1649  1136797108156002304  1136797108156002304  1559868525000
# 99998   1650  1136796835287142401  1136796835287142401  1559868460000
# 99999   1651  1136796718698180613  1136792197175664640  1559868433000
#
#                       date timezone place  \
# 99995  2019-06-07 00:51:26      UTC
# 99996  2019-06-07 00:50:27      UTC
# 99997  2019-06-07 00:48:45      UTC
# 99998  2019-06-07 00:47:40      UTC
# 99999  2019-06-07 00:47:13      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  Pete Buttigieg with the only acceptable answer...       []       []
# 99996  As a diehard @NSYNC fan I might have to rethin...       []       []
# 99997  Very thoughtful words. Mayor @PeteButtigieg Pe...       []       []
# ...

# %%
Buttigieg3 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-06-07 00:40:00") AND (name = "BUTTIGIEG") LIMIT 100000;', con = engine)
Buttigieg3.to_csv('DATA/Buttigieg3.csv')
Buttigieg3.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 99995    569  1159549779241840641  1159549779241840641  1565293185000
# 99996    570  1159549614741250049  1159547341948563456  1565293146000
# 99997    571  1159549396213571584  1159214116009140225  1565293094000
# 99998    572  1159549254135926784  1159541275860750336  1565293060000
# 99999    573  1159549237337743361  1159547341948563456  1565293056000
#
#                       date timezone place  \
# 99995  2019-08-08 19:39:45      UTC
# 99996  2019-08-08 19:39:06      UTC
# 99997  2019-08-08 19:38:14      UTC
# 99998  2019-08-08 19:37:40      UTC
# 99999  2019-08-08 19:37:36      UTC
#
#                                                    tweet hashtags cashtags  \
# 99995  I was just going through hubby's movies puttin...       []       []
# 99996               Warren/Mayor Pete is my dream ticket       []       []
# 99997  You seem like a nice guy, Pete. Too bad your t...       []       []
# ...

# %%
Buttigieg4 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-08-08 19:00:00") AND (name = "BUTTIGIEG") LIMIT 50000;', con = engine)
Buttigieg4.to_csv('DATA/Buttigieg4.csv')
Buttigieg4.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995   6580  1172363448795009024  1172362666117074945  1568348202000
# 49996   6581  1172363439827824640  1172302252238954496  1568348200000
# 49997   6582  1172363426758180864  1172296150348513281  1568348197000
# 49998   6583  1172363376334266369  1172340128183771137  1568348185000
# 49999   6584  1172363359523672064  1172363359523672064  1568348181000
#
#                       date timezone place  \
# 49995  2019-09-13 04:16:42      UTC
# 49996  2019-09-13 04:16:40      UTC
# 49997  2019-09-13 04:16:37      UTC
# 49998  2019-09-13 04:16:25      UTC
# 49999  2019-09-13 04:16:21      UTC
#
#                                                    tweet  \
# 49995                              Thank you Mayor Pete!
# 49996  Mayor Pete is my favorite, but I don’t believe...
# 49997                I love you Pete! #PeteButtigieg2020
# 49998  Mayor Pete stood out when the moderators gave ...
# ...

# %%
Buttigieg5 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-09-13 04:00:00") AND (name = "BUTTIGIEG") LIMIT 50000;', con = engine)
Buttigieg5.to_csv('DATA/Buttigieg5.csv')
Buttigieg5.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 49995    713  1185607717152444417  1185349262307135495  1571505881000
# 49996    714  1185607600852721664  1185607600852721664  1571505854000
# 49997    715  1185607529029439488  1185511675434295296  1571505837000
# 49998    716  1185607136446947330  1185289626409406464  1571505743000
# 49999    717  1185606952556126208  1185247365323579392  1571505699000
#
#                       date timezone place  \
# 49995  2019-10-19 17:24:41      UTC
# 49996  2019-10-19 17:24:14      UTC
# 49997  2019-10-19 17:23:57      UTC
# 49998  2019-10-19 17:22:23      UTC
# 49999  2019-10-19 17:21:39      UTC
#
#                                                    tweet hashtags cashtags  \
# 49995  Nope! Sorry Mayor Pete, we do not need “unions...       []       []
# 49996  Celebrities and politicians affirming Yang pol...       []       []
# 49997  Mayor pete copies yang word for word sometimes...       []       []
# ...

# %%
Buttigieg6 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-19 04:00:00") AND (name = "BUTTIGIEG") LIMIT 30000;', con = engine)
Buttigieg6.to_csv('DATA/Buttigieg6.csv')
Buttigieg6.tail()
# Out:
#        index                   id      conversation_id     created_at  \
# 11056   1722  1188969088296505345  1188931850225491970  1572307295000
# 11057   1723  1188968983086747648  1188619028174127105  1572307270000
# 11058   1724  1188968810507837440  1188968810507837440  1572307229000
# 11059   1725  1188968810038120449  1188967418640699392  1572307228000
# 11060   1726  1188968735253696515  1188968735253696515  1572307211000
#
#                       date timezone place  \
# 11056  2019-10-29 00:01:35      UTC
# 11057  2019-10-29 00:01:10      UTC
# 11058  2019-10-29 00:00:29      UTC
# 11059  2019-10-29 00:00:28      UTC
# 11060  2019-10-29 00:00:11      UTC
#
#                                                    tweet       hashtags  \
# 11056              Has a kid shown up dressed like Pete?             []
# 11057  I beg to differ with you. I respect Mayor Pete...             []
# 11058  #hardball Mayor Pete is polling at 1% with bla...  ['#hardball']
# ...

# %%
Buttigieg7 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-29 00:00:00") AND (name = "BUTTIGIEG") LIMIT 20000;', con = engine)
Buttigieg7.to_csv('DATA/Buttigieg7.csv')
Buttigieg7.tail()
# Out:
#       index                   id      conversation_id     created_at  \
# 1722   1722  1188969088296505345  1188931850225491970  1572307295000
# 1723   1723  1188968983086747648  1188619028174127105  1572307270000
# 1724   1724  1188968810507837440  1188968810507837440  1572307229000
# 1725   1725  1188968810038120449  1188967418640699392  1572307228000
# 1726   1726  1188968735253696515  1188968735253696515  1572307211000
#
#                      date timezone place  \
# 1722  2019-10-29 00:01:35      UTC
# 1723  2019-10-29 00:01:10      UTC
# 1724  2019-10-29 00:00:29      UTC
# 1725  2019-10-29 00:00:28      UTC
# 1726  2019-10-29 00:00:11      UTC
#
#                                                   tweet       hashtags  \
# 1722              Has a kid shown up dressed like Pete?             []
# 1723  I beg to differ with you. I respect Mayor Pete...             []
# 1724  #hardball Mayor Pete is polling at 1% with bla...  ['#hardball']
# ...

# %%
Buttigieg8 = pd.read_sql(f'SELECT * FROM tweets WHERE (date >= "2019-10-30 00:00:00") AND (name = "BUTTIGIEG") LIMIT 20000;', con = engine)
Buttigieg8.to_csv('DATA/Buttigieg8.csv')
Buttigieg8.tail()
# Out:
# Empty DataFrame
# Columns: [index, id, conversation_id, created_at, date, timezone, place, tweet, hashtags, cashtags, user_id, user_id_str, username, name, day, hour, link, retweet, nlikes, nreplies, nretweets, quote_url, search, near, geo, source, user_rt_id, user_rt, retweet_id, reply_to, retweet_date]
# Index: []
