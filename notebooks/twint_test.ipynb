# %%
from datetime import datetime as dt
from datetime import timedelta

import pandas as pd

from twitpol import config, utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.set_option('display.max_columns', 999)

# %%
pd.read_csv('../data/twint_test.csv')
# Out:
#                       id      conversation_id     created_at        date  \
# 0    1123074487237234690  1123063323463962625  1556596798000  2019-04-29
# 1    1123074459135619072  1123072670654799872  1556596791000  2019-04-29
# 2    1123074431197147136  1123074431197147136  1556596784000  2019-04-29
# 3    1123074422246649856  1123074422246649856  1556596782000  2019-04-29
# 4    1123074348867313665  1123074348867313665  1556596765000  2019-04-29
# ..                   ...                  ...            ...         ...
# 335  1123069623803498496  1122570639733329920  1556595638000  2019-04-29
# 336  1123069619529572352  1122950661665120261  1556595637000  2019-04-29
# 337  1123069608091500544  1122565592106643456  1556595634000  2019-04-29
# 338  1123069606346682368  1123069606346682368  1556595634000  2019-04-29
# 339  1123069606061416449  1123069606061416449  1556595634000  2019-04-29
#
#          time timezone              user_id       username  \
# ...

# %%
d1_str = '2019-01-01'
d2_str = '2019-11-04'
step = 1

# %%
dategen = utils.date_range(d1_str, d2_str, step=1)

# %%
for d1, d2 in dategen:
    print(d1, d2)
# Out:
# 2019-01-01 2019-01-02
# 2019-01-02 2019-01-03
# 2019-01-03 2019-01-04
# 2019-01-04 2019-01-05
# 2019-01-05 2019-01-06
# 2019-01-06 2019-01-07
# 2019-01-07 2019-01-08
# 2019-01-08 2019-01-09
# 2019-01-09 2019-01-10
# 2019-01-10 2019-01-11
# 2019-01-11 2019-01-12
# 2019-01-12 2019-01-13
# 2019-01-13 2019-01-14
# 2019-01-14 2019-01-15
# 2019-01-15 2019-01-16
# 2019-01-16 2019-01-17
# 2019-01-17 2019-01-18
# 2019-01-18 2019-01-19
# 2019-01-19 2019-01-20
# 2019-01-20 2019-01-21
# 2019-01-21 2019-01-22
# 2019-01-22 2019-01-23
# 2019-01-23 2019-01-24
# 2019-01-24 2019-01-25
# 2019-01-25 2019-01-26
# 2019-01-26 2019-01-27
# 2019-01-27 2019-01-28
# 2019-01-28 2019-01-29
# 2019-01-29 2019-01-30
# 2019-01-30 2019-01-31
# 2019-01-31 2019-02-01
# 2019-02-01 2019-02-02
# 2019-02-02 2019-02-03
# 2019-02-03 2019-02-04
# 2019-02-04 2019-02-05
# 2019-02-05 2019-02-06
# 2019-02-06 2019-02-07
# 2019-02-07 2019-02-08
# 2019-02-08 2019-02-09
# 2019-02-09 2019-02-10
# 2019-02-10 2019-02-11
# ...

# %%
step = timedelta(days=1)
fmt_str = '%Y-%m-%d'

d1 = dt.strptime(d1_str, fmt_str)
d2 = dt.strptime(d2_str, fmt_str)

# %%
d1
# Out:
# datetime.datetime(2019, 1, 1, 0, 0)

# %%
d2
# Out:
# datetime.datetime(2019, 11, 4, 0, 0)

# %%
(d2 - d1).days
# Out:
# 307

# %%
step
# Out:
# datetime.timedelta(days=1)

# %%
curr_date = d1 + step

# %%
curr_date
# Out:
# datetime.datetime(2019, 1, 2, 0, 0)

# %%
curr_date <= d2
# Out:
# True

# %%
int(curr_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9d5270526848> in <module>
# ----> 1 int(curr_date)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'datetime.datetime'

# %%
i = 0
curr_date = d1
while curr_date <= d2:
    if i % 50 == 0:
        print(curr_date)
    curr_date += step
    i += 1
# Out:
# 2019-01-01 00:00:00
# 2019-02-20 00:00:00
# 2019-04-11 00:00:00
# 2019-05-31 00:00:00
# 2019-07-20 00:00:00
# 2019-09-08 00:00:00
# 2019-10-28 00:00:00

# %%
dt.today().date()
# Out:
# datetime.date(2019, 11, 9)
