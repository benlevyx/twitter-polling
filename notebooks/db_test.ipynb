# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

from twitpol import config, db

# %%
pd.set_option('display.max_columns', 999)

# %%
host = 'database-2.czpegg91dqsv.us-east-2.rds.amazonaws.com'
port = 3306
user = 'admin'
password = 'dbpass111'
charset = 'utf8'
database = 'test_2'

db_str = f'mysql+pymysql://{user}:{password}@{host}:{port}/'
engine = create_engine(db_str)
engine.connect().execute(f"CREATE DATABASE IF NOT EXISTS {database};")
db_str_new = db_str + database
engine_new = create_engine(db_str_new)
# Out:
# /home/ubuntu/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1007, "Can't create database 'test_2'; database exists")
#   result = self._query(query)

# %%
df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'age': [12, 13, 14, 15]
})
df
# Out:
#   name  age
# 0    A   12
# 1    B   13
# 2    C   14
# 3    D   15

# %%
df.to_sql('test_table', con=engine_new, if_exists='append')

# %%
pd.read_sql('SELECT * FROM test_table;', con=engine_new, index_col='index')
# Out:
#       name  age
# index
# 0        A   12
# 1        B   13
# 2        C   14
# 3        D   15

# %%
engine = db.get_db_engine(create_database=False)

# %%
pd.read_sql(f'SELECT * FROM tweets WHERE name = "WARREN";', con=engine)

# %%
pd.read_sql('SELECT COUNT(*) FROM tweets;', con=engine)
# Out:
#    COUNT(*)
# 0     99124

# %%
pd.read_sql('SELECT * FROM tweets;', con=engine).tail(10)
# Out:
#        index                   id      conversation_id     created_at  \
# 99114   3709  1112835208804556801  1112835208804556801  1554155563000
# 99115   3710  1112835201577766912  1112835201577766912  1554155562000
# 99116   3711  1112835184724860928  1112835184724860928  1554155558000
# 99117   3712  1112835160842620931  1112835160842620931  1554155552000
# 99118   3713  1112835146162626561  1112835146162626561  1554155548000
# 99119   3714  1112835145806036992  1112833731713130498  1554155548000
# 99120   3715  1112835144350658560  1112835144350658560  1554155548000
# 99121   3716  1112835124406566912  1112791380768616449  1554155543000
# 99122   3717  1112835079603191808  1112835079603191808  1554155533000
# 99123   3718  1112835064541429766  1112793964447449088  1554155529000
#
#                       date timezone place  \
# 99114  2019-04-01 21:52:43      UTC
# 99115  2019-04-01 21:52:42      UTC
# 99116  2019-04-01 21:52:38      UTC
# 99117  2019-04-01 21:52:32      UTC
# 99118  2019-04-01 21:52:28      UTC
# 99119  2019-04-01 21:52:28      UTC
# 99120  2019-04-01 21:52:28      UTC
# 99121  2019-04-01 21:52:23      UTC
# 99122  2019-04-01 21:52:13      UTC
# 99123  2019-04-01 21:52:09      UTC
#
#                                                    tweet  \
# 99114  Joy Behar Defends Creepy Joe Biden: 'He Touche...
# 99115  Impeached President Bill Clinton's crime boss ...
# 99116  Connecticut woman says then-Vice President Joe...
# 99117  I have to say watching the socialist attack a ...
# 99118  'Gropey Uncle' Joe Biden has always been creep...
# 99119  I dare to think of everything Joe Biden may ha...
# 99120  An Awkward Kiss Changed How I Saw Joe Biden  h...
# 99121                                  Creepy Joe Biden.
# 99122  I am not a huge fan of Joe Biden and wouldn’t ...
# 99123  Creepy Uncle Joe Boner Biden ...his days of th...
#
#                                                 hashtags cashtags     user_id  \
# 99114                                           ['#aag']       []  1494835716
# 99115  ['#berniesanders', '#joebiden', '#joebidensnif...       []   174873047
# 99116                                                 []       []   708199243
# 99117  ['#moron', '#liar', '#mutt', '#trumptrain2020'...       []    24635878
# 99118                                                 []       []   736095344
# 99119                                       ['#sniffed']       []  3301554829
# 99120                                                 []       []   102135961
# 99121                                                 []       []    79768881
# 99122                                                 []       []  3158646817
# 99123                                                 []       []    45982350
#
#       user_id_str         username   name  day hour  \
# 99114  1494835716  AIIAmericanGirI  BIDEN    1   14
# 99115   174873047  will_the_thrilI  BIDEN    1   14
# 99116   708199243      NCManoukian  BIDEN    1   13
# 99117    24635878     shocker23456  BIDEN    1   11
# 99118   736095344          WTPatty  BIDEN    1   10
# 99119  3301554829    thiviergemike  BIDEN    1   10
# 99120   102135961     JesseConover  BIDEN    1   10
# 99121    79768881   Hypidiomorphic  BIDEN    1   09
# 99122  3158646817       rhiggins00  BIDEN    1   06
# 99123    45982350    lightchaser17  BIDEN    1   05
#
#                                                     link  retweet  nlikes  \
# 99114  https://twitter.com/AIIAmericanGirI/status/111...        0       2
# 99115  https://twitter.com/will_the_thrilI/status/111...        0       0
# 99116  https://twitter.com/NCManoukian/status/1112835...        0       0
# 99117  https://twitter.com/shocker23456/status/111283...        0       1
# 99118  https://twitter.com/WTPatty/status/11128351461...        0       2
# 99119  https://twitter.com/thiviergemike/status/11128...        0       1
# 99120  https://twitter.com/JesseConover/status/111283...        0       0
# 99121  https://twitter.com/Hypidiomorphic/status/1112...        0       0
# 99122  https://twitter.com/rhiggins00/status/11128350...        0       0
# 99123  https://twitter.com/lightchaser17/status/11128...        0       1
#
#        nreplies  nretweets                                          quote_url  \
# 99114         1          1
# 99115         0          0
# 99116         0          0
# 99117         0          3
# 99118         0          0
# 99119         0          0
# 99120         0          0
# 99121         0          0
# 99122         0          0  https://twitter.com/AutohistorianUS/status/111...
# 99123         0          0
#
#                                                   search near geo source  \
# 99114  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99115  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99116  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99117  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99118  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99119  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99120  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99121  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99122  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
# 99123  Joe Biden OR "Joseph Biden" OR "Biden" OR "Dia...
#
#       user_rt_id user_rt retweet_id  \
# 99114
# 99115
# 99116
# 99117
# 99118
# 99119
# 99120
# 99121
# 99122
# 99123
#
#                                                 reply_to retweet_date
# 99114  [{'user_id': '1494835716', 'username': 'AIIAme...
# 99115  [{'user_id': '174873047', 'username': 'will_th...
# 99116  [{'user_id': '708199243', 'username': 'NCManou...
# 99117  [{'user_id': '24635878', 'username': 'shocker2...
# 99118  [{'user_id': '736095344', 'username': 'WTPatty...
# 99119  [{'user_id': '3301554829', 'username': 'thivie...
# 99120  [{'user_id': '102135961', 'username': 'JesseCo...
# 99121  [{'user_id': '79768881', 'username': 'Hypidiom...
# 99122  [{'user_id': '3158646817', 'username': 'rhiggi...
# 99123  [{'user_id': '45982350', 'username': 'lightcha...
