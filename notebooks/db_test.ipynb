# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

from twitpol import config, db

# %%
pd.set_option('display.max_columns', 999)

# %%
host = 'database-2.czpegg91dqsv.us-east-2.rds.amazonaws.com'
port = 3306
user = 'admin'
password = 'dbpass111'
charset = 'utf8'
database = 'test_2'

db_str = f'mysql+pymysql://{user}:{password}@{host}:{port}/'
engine = create_engine(db_str)
engine.connect().execute(f"CREATE DATABASE IF NOT EXISTS {database};")
db_str_new = db_str + database
engine_new = create_engine(db_str_new)
# Out:
# /home/ubuntu/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1007, "Can't create database 'test_2'; database exists")
#   result = self._query(query)

# %%
df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'age': [12, 13, 14, 15]
})
df
# Out:
#   name  age
# 0    A   12
# 1    B   13
# 2    C   14
# 3    D   15

# %%
df.to_sql('test_table', con=engine_new, if_exists='append')

# %%
pd.read_sql('SELECT * FROM test_table;', con=engine_new, index_col='index')
# Out:
#       name  age
# index
# 0        A   12
# 1        B   13
# 2        C   14
# 3        D   15

# %%
engine = db.get_db_engine(create_database=False)

# %%
pd.read_sql(f'SELECT * FROM tweets_db LIMIT 100;', con=engine)
# Out:
#     index                   id      conversation_id     created_at  \
# 0       0  1080252272637038597  1080244340839116810  1546387186000
# 1       1  1080252220204027904  1080189345259315209  1546387174000
# 2       2  1080252076658180096  1080189345259315209  1546387139000
# 3       3  1080251922286813187  1079871719861600257  1546387103000
# 4       4  1080251916678967296  1080248896444612610  1546387101000
# ..    ...                  ...                  ...            ...
# 95     95  1080239978100203521  1080235018310635521  1546384255000
# 96     96  1080239524913934337  1080235676254289921  1546384147000
# 97     97  1080239223699955713  1080239223699955713  1546384075000
# 98     98  1080238649789173760  1079871719861600257  1546383938000
# 99     99  1080238589575860224  1080238589575860224  1546383924000
#
#                    date timezone      place  \
# 0   2019-01-01 23:59:46      UTC
# 1   2019-01-01 23:59:34      UTC  Bronx, NY
# 2   2019-01-01 23:58:59      UTC
# ...

# %%
pd.read_sql('SELECT COUNT(*) FROM tweets_db;', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# ~/miniconda3/envs/twitpol-env/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
engine.execute('DROP TABLE IF EXISTS tweets_db')
